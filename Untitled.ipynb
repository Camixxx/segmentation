# %%
run main.py
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:198: UserWarning: NLLLoss2d has been deprecated. Please use NLLLoss instead as a drop-in replacement and see http://pytorch.org/docs/master/nn.html#torch.nn.NLLLoss for more details.
#   warnings.warn("NLLLoss2d has been deprecated. "
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/upsampling.py:221: UserWarning: nn.UpsamplingBilinear2d is deprecated. Use nn.Upsample instead.
#   warnings.warn("nn.UpsamplingBilinear2d is deprecated. Use nn.Upsample instead.")
# /home/VOC/my_torch/utils.py:48: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.nll_loss(F.log_softmax(inputs), targets)
# /home/VOC/my_torch/main.py:92: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   writer.add_scalar('loss', loss.data[0], i)
# ...
